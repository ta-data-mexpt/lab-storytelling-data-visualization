# %% [markdown]
# # Storytelling Data Visualization Lab
#
# In this lab you'll use a dataset called `housing_prices.csv` which contains the sales data of houses. The dataset and descriptions of the columns are available from [Kaggle](https://www.kaggle.com/c/house-prices-advanced-regression-techniques/data). For your convenience, you can review the descriptions of the data columns from [here](data-description.txt).
#
# Pretend you are a data analyst at an investment company where the board decided to make investments in real estates. Your boss asked you to analyze this housing sales dataset and present to the investment managers on **what features of houses are strong indicators of the final sale price**. You need to present your findings in intuitive ways so that the investment managers understand where your conclusions come from.
#
# #### You will use the appropriate data visualization graphs to tell your stories.

# %% [markdown]
# ## Challenge 1 - Understanding the Dataset
#
# After receiving the data and clarifying your objectives with your boss, you will first try to understand the dataset. This allows you to decide how you will start your research in the next step.
#
# #### First, import the basic libraries and the dataset.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('housing_prices.csv')

# %% [markdown]
# #### As a routine before analyzing a dataset, print the first few rows of the dataset

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %% [markdown]
# You find the dataset has 81 columns which are a lot.
#
# #### Since the column `Id` is meaningless in our data visualization work, let's drop it

# %%
# your code here
df.drop(['Id'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          60       RL         65.0     8450   Pave   NaN      Reg
# 1          20       RL         80.0     9600   Pave   NaN      Reg
# 2          60       RL         68.0    11250   Pave   NaN      IR1
# 3          70       RL         60.0     9550   Pave   NaN      IR1
# 4          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# 0         Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 1         Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
# 2         Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 3         Lvl    AllPub    Corner  ...        0    NaN   NaN         NaN
# 4         Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# 0       0      2    2008        WD         Normal     208500
# ...

# %%
df.shape
# Out:
# (1460, 80)

# %% [markdown]
# You care about missing values. If a column has too many missing values, it is not reliable to use it to predict sales price.
#
# #### In the cell below, calculate the percentage of missing values for each column.
#
# Make a table containing the column name and the percentage of missing values. Print the columns where more than 20% of values are missing. An example of your output looks like:
#
# ![Missing Values](missing-values.png)
#
# [This reference](https://stackoverflow.com/questions/51070985/find-out-the-percentage-of-missing-values-in-each-column-in-the-given-dataset) can help you make the missing values table.

# %%
percent_missing = df.isnull().sum() * 100 / len(df)
missing_value_df = pd.DataFrame({'column_name': df.columns,
                                 'percent_missing': percent_missing})
missing_value_df.sort_values('percent_missing', inplace=True, ascending=[False])
missing_value_df
# Out:
#              column_name  percent_missing
# PoolQC            PoolQC        99.520548
# MiscFeature  MiscFeature        96.301370
# Alley              Alley        93.767123
# Fence              Fence        80.753425
# FireplaceQu  FireplaceQu        47.260274
# ...                  ...              ...
# Heating          Heating         0.000000
# HeatingQC      HeatingQC         0.000000
# MSZoning        MSZoning         0.000000
# 1stFlrSF        1stFlrSF         0.000000
# SalePrice      SalePrice         0.000000
#
# [80 rows x 2 columns]

# %% [markdown]
# #### Drop the columns you find that have more than 20% missing values.
#
# After dropping, check the shape of your dataframes. You should have 75 columns now.

# %%
col_drop=missing_value_df[missing_value_df.percent_missing > 20].index
col_drop
# Out:
# Index(['PoolQC', 'MiscFeature', 'Alley', 'Fence', 'FireplaceQu'], dtype='object')

# %%
df.drop(col_drop, axis=1, inplace=True)

# %%
df.shape
# Out:
# (1460, 75)

# %% [markdown]
# Since you're asked to analyze sale prices, first let's see if the sale prices (column `SalePrice`) has a normal distribution. This is important because normally distributed data can be better represented with mathematical models.
#
# #### In the cell below, use the propriate graph to visualize the shape of distribution of the sale prices. Then explain what you find from the graph about data distribution.

# %%
# your code here
plt.figure(figsize = (6, 3))
plt.hist(df['SalePrice'], alpha=0.5)
# Out:
# (array([148., 723., 373., 135.,  51.,  19.,   4.,   3.,   2.,   2.]),
#  array([ 34900., 106910., 178920., 250930., 322940., 394950., 466960.,
#         538970., 610980., 682990., 755000.]),
#  <BarContainer object of 10 artists>)

# %%
# your comment here
'''
La mayoría de los valores de precio de venta estan dentro del rango de los 50,000 a los 450,000
con pocos valores extremos.
'''
# Out:
# '\nLa mayoría de los valores de precio de venta estan dentro del rango de los 50,000 a los 450,000\ncon pocos valores extremos.\n'

# %% [markdown]
# ## Bonus Challenge 1 - Adjust Data Distribution
#
# If you used the correct method in the previous step, you should have found the data distribution is skewed to the left. In order to improve your data visualization in the next steps, you can opt to adjust the `SalePrice` column by applying a mathematical function to the values. The goal is to produce a bell-shape normal distribution after applying the mathematical function to the sale price.
#
# *This technique is optional in data visualization but you'll find it useful in your future machine learning analysis.*
#
# #### In the cell below, adjust the `SalePrice` column so that the data are normally distributed.
#
# Try applying various mathematical functions such as square root, power, and log to the `SalePrice` column. Visualize the distribution of the adjusted data until you find a function that makes the data normally distributed. **Create a new column called `SalePriceAdjusted` to store the adjusted sale price.**
#
# [This reference](https://trainingdatascience.com/workshops/histograms-and-skewed-data/) shows you examples on how to adjust skewed data.

# %%
# your code here
df['SalePriceAdjusted'] = df['SalePrice'].apply(np.sqrt)
df['SalePriceAdjusted'].plot.hist(alpha=0.5, grid=True, legend=None)
plt.show()
df.columns
# Out:
# Index(['MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Functional', 'Fireplaces', 'GarageType', 'GarageYrBlt', 'GarageFinish',
#        'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond', 'PavedDrive',
# ...

# %% [markdown]
# ## Challenge 2 - Exploring Data with Common Sense
#
# Now that we have a general understanding of the dataset, we start exploring the data with common sense by means of data visualization. Yes, in data analysis and even machine learning you are often required to use common sense. You use your common sense to make a scientific guess (i.e. hypothesis) then use data analytics methods to test your hypothesis.
#
# This dataset is about housing sales. According to common sense, housing prices depend on the following factors:
#
# * **Size of the house** (`GrLivArea`, `LotArea`, and `GarageArea`).
#
# * **Number of rooms** (`BedroomAbvGr`, `KitchenAbvGr`, `FullBath`, `HalfBath`, `BsmtFullBath`, `BsmtHalfBath`).
#
# * **How long the house has been built or remodeled** (`YearBuilt` and `YearRemodAdd`).
#
# * **Neighborhood of the house** (`Neighborhood`).
#
# #### In this challenge, use the appropriate graph type to visualize the relationships between `SalePrice` (or `SalePriceAdjusted`) and the fields above.
#
# Note that:
#
# * Transform certain columns in order to visualize the data properly based on common sense. For example:
#     * Visualizing how the number of half bathrooms affected the sale price probably does not make sense. You can create a new column to calculate the total number of bathrooms/rooms then visualize with the calculated number.
#     * `YearBuilt` and `YearRemodAdd` are year numbers not the age of the house. You can create two new columns for how long the house has been built or remodeled then visualize with the calculated columns.
# * Make comments to explain your thinking process.

# %%
# your code here
# add cells as needed
df["Total_Rooms"]=df[['BedroomAbvGr', 'KitchenAbvGr', 'FullBath', 'HalfBath', 'BsmtFullBath', 'BsmtHalfBath']].sum(axis=1)
df.columns
# Out:
# Index(['MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Functional', 'Fireplaces', 'GarageType', 'GarageYrBlt', 'GarageFinish',
#        'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond', 'PavedDrive',
# ...

# %%
sns.scatterplot(x = 'Total_Rooms', y = 'SalePrice', data = df, palette="Blues_d")
# Out:
# <AxesSubplot:xlabel='Total_Rooms', ylabel='SalePrice'>

# %%
df[['YearBuilt', 'YearRemodAdd']].head()
# Out:
#    YearBuilt  YearRemodAdd
# 0       2003          2003
# 1       1976          1976
# 2       2001          2002
# 3       1915          1970
# 4       2000          2000

# %%
df['TimeBuilt']= 2022- df['YearBuilt']
df['TimeBuilt'].head()
# Out:
# 0     19
# 1     46
# 2     21
# 3    107
# 4     22
# Name: TimeBuilt, dtype: int64

# %%
sns.scatterplot(x = 'TimeBuilt', y = 'SalePrice', data = df, palette="Blues_d")
# Out:
# <AxesSubplot:xlabel='TimeBuilt', ylabel='SalePrice'>

# %%
df['TimeRemo']= 2022- df['YearRemodAdd']
df['TimeRemo'].head()
# Out:
# 0    19
# 1    46
# 2    20
# 3    52
# 4    22
# Name: TimeRemo, dtype: int64

# %%
sns.scatterplot(x = 'TimeRemo', y = 'SalePrice', data = df, palette="Blues_d")
# Out:
# <AxesSubplot:xlabel='TimeRemo', ylabel='SalePrice'>

# %%
'''
El número de habitaciones, si bien tiene un rango aplio de precios, si permite observar que entre más habitaciones tiene, entonces 
el rango de precio es mayor.
Por otra parte el tiempo de construcción se observa que hay mayor variedad y mejores de precios de venta conforme la construcción es más reciente, 
con muy pocos mayores a 120 años, mientras que el tiempo de remodelación donde el valor máximo es menor a 80 años, mustra valores de venta diversos 
aunque más favorables cuando es menor a 30 años.
'''
# Out:
# '\nEl número de habitaciones, si bien tiene un rango aplio de precios, si permite observar que entre más habitaciones tiene, entonces \nel rango de precio es mayor.\nPor otra parte el tiempo de construcción se observa que hay mayor variedad y mejores de precios de venta conforme la construcción es más reciente, \ncon muy pocos mayores a 120 años, mientras que el tiempo de remodelación donde el valor máximo es menor a 80 años, mustra valores de venta diversos \naunque más favorables cuando es menor a 30 años.\n'

# %% [markdown]
# ## Bonus Challenge 2 - Exploring Data with Correlation Heatmap
#
# Now you have explored data visualizations with certain fields based on common sense. In the dataset there are many other fields that you are not sure whether they are important factors for the sale price. What is the best way to explore those fields without investigating them individually?
#
# Making scatter matrix is not an option here because there are too many fields which makes it extremely time consuming to create scatter matrix. One option you have is to create a heatmap. Heatmaps are much less expensive to create than scatter matrixes. You can use heatmaps to visualize the pairwise correlations between each two variables.
#
# Here is a [reference](https://seaborn.pydata.org/examples/many_pairwise_correlations.html) you can use to learn how to creat the pairwise correlation heatmap. Your heatmap should look like below:
#
# ![Corr Heatmap](heatmap.png)

# %%
# your code here
numerical= df.select_dtypes(include=['number'])
corr= numerical.corr()
mask = np.triu(np.ones_like(corr, dtype = bool))

# %%
cmap = sns.diverging_palette(2020, 10, as_cmap = True)

# %%
plt.figure(figsize = (10,10))
sns.heatmap(corr, mask=mask,cmap = cmap, vmax = 1, vmin = -1, annot = False, square = True, center = 0, linewidths = 0.3, )
# Out:
# <AxesSubplot:>

# %% [markdown]
# In your heatmap, you can easily identify the highly correlated (either positively or negatively) variables by looking for the grids with darker colors.
#
# #### In the cell below, summarize what variables are highly correlated to the sale price?

# %%
# your comment here
'''
Las variables más correlacionadas positivamente con el precio de venta son la calidad de los materiales y los acabados (OverallQual), 
el total de pies cuadrados de superficie de sótano (TotalBsmtSF), la cantidad de pies cuadrados del primer piso (1stFlrSF), 
la superficie habitable por encima del nivel del suelo (GrLivArea), la cantidad de baños completos(FullBath), así como el área relacionada
con el Garage(GarageCars y GarageArea). Todas estas variables indican que las superficies y acabados son los factores más importantes 
respecto al aumento en eñ valor de venta de una propiedad.

Por otro lado una correlación fuerte negativa es la que hay entre los años de construcción y remodelación con el precio, ya que entre mayor sea
la diferencia entre estos, menor será el precio de venta. 
'''
# Out:
# '\nLas variables más correlacionadas positivamente con el precio de venta son la calidad de los materiales y los acabados (OverallQual), \nel total de pies cuadrados de superficie de sótano (TotalBsmtSF), la cantidad de pies cuadrados del primer piso (1stFlrSF), \nla superficie habitable por encima del nivel del suelo (GrLivArea), la cantidad de baños completos(FullBath), así como el área relacionada\ncon el Garage(GarageCars y GarageArea). Todas estas variables indican que las superficies y acabados son los factores más importantes \nrespecto al aumento en eñ valor de venta de una propiedad.\n\nPor otro lado una correlación fuerte negativa es la que hay entre los años de construcción y remodelación con el precio, ya que entre mayor sea\nla diferencia entre estos, menor será el precio de venta. \n'

# %% [markdown]
# ## Challenge 3 - Present Your Stories
#
# Now based on your findings from the explorations, summarize and present your stories.
#
# #### Present the top 5 factors that affect the sale price.
#
# Use the following format to present each factor:
#
# 1. A title line about the factor.
#
# 1. No more than 3 sentences to describe the relationship between the factor and the sale price.
#
# 1. Support your point with the appropriate graph.

# %%
stories= df[['OverallQual','TotalBsmtSF', 'GrLivArea', 'GarageCars', 'GarageArea', 'TimeBuilt', 'TimeRemo','SalePrice' ]]
stories.corr()
# Out:
#              OverallQual  TotalBsmtSF  GrLivArea  GarageCars  GarageArea  \
# OverallQual     1.000000     0.537808   0.593007    0.600671    0.562022
# TotalBsmtSF     0.537808     1.000000   0.454868    0.434585    0.486665
# GrLivArea       0.593007     0.454868   1.000000    0.467247    0.468997
# GarageCars      0.600671     0.434585   0.467247    1.000000    0.882475
# GarageArea      0.562022     0.486665   0.468997    0.882475    1.000000
# TimeBuilt      -0.572323    -0.391452  -0.199010   -0.537850   -0.478954
# TimeRemo       -0.550684    -0.291066  -0.287389   -0.420622   -0.371600
# SalePrice       0.790982     0.613581   0.708624    0.640409    0.623431
#
#              TimeBuilt  TimeRemo  SalePrice
# OverallQual  -0.572323 -0.550684   0.790982
# TotalBsmtSF  -0.391452 -0.291066   0.613581
# GrLivArea    -0.199010 -0.287389   0.708624
# GarageCars   -0.537850 -0.420622   0.640409
# GarageArea   -0.478954 -0.371600   0.623431
# ...

# %% [markdown]
# ## FACTORES RELACIONADOS AL PRECIO DE VENTA DE UNA CASA

# %% [markdown]
# #### Relación de precio con calidad de los materiales y los acabados del inmueble.
#
# La calidad de los materiales y los acabados son factores de suma importancia para ajustar el precio de venta de un
# inmueble, ya que cambian la estética del inmueble y hablan del cuidado que se ha tenido en conservar la propiedad,
# así como la calidad de los mismos para no causar problemas a futuro.

# %%
sns.set_style("darkgrid")
sns.scatterplot(x = 'OverallQual', y = 'SalePrice', data = stories, color="#9b59b6", alpha = 0.7)
plt.show()

# %% [markdown]
# #### Relación del precio con total de pies cuadrados de construcción de sótano.
#
# Como se muestra en la figura,  el precio de venta aumenta en relación con el total de la superficie de construcción del sótano, esto indica la importacia de este espacio para los compradores, pues es un espacio que puede ser empleado para diferentes usos sin interferir en la distribución del piso principal del inmueble.

# %%
sns.set_style("darkgrid")
sns.scatterplot(x = 'TotalBsmtSF', y = 'SalePrice', data = stories, color="#38d2aa", alpha = 0.5)
plt.show()

# %% [markdown]
# #### Relación del precio con el área de Garage y la capacidad de autos en el mismo.
#
# En la siguiente figura, se puede observar la estrecha relación que existe entre el precio del inmueble y la zona destinada como garage para ambos aspectos:
# 1. Area del garage en pies cuadrados
# 1. Tamaño del garage en capacidad de autos
#
# Actualmente la importancia de contar con un espacio propio para guardar los automóviles es de suma importancia y valor para los compradores.

# %%
cols=['GarageArea','GarageCars', 'SalePrice']
df=stories[cols]
fig,axes = plt.subplots(figsize = (12,6), nrows = 1, ncols = 2)
for i in range(2):
    plt.sca(axes[i])
    plt.scatter(df.iloc[:,i],df['SalePrice'], color="#cf580f", alpha = 0.6)
    plt.xlabel(df.iloc[:,i].name)
    plt.ylabel('SalesPrice')

# %% [markdown]
# #### Relación del precio de venta y la superficie habitable sobre el nivel del suelo
#
# Como última correlación positiva para el precio de venta de la casa, se encuentra uno de los factores que resume otros como la cantidad de habitaciones, el área construida en para el rpimer piso, el número de baños medios y completos, esta es el Área total de pies cuadrados habitable sobre el nivel del suelo, cuya medición nos indica el tamaño de la casa y a pesar de otros factores externos, es determinante para obtener el valor de venta.

# %%
sns.lmplot(x='GrLivArea',y='SalePrice', data=stories ,fit_reg=True) 
plt.show()

# %% [markdown]
# #### Relación del precio de venta y los años de construcción y remodelación.
#
# Finalmente podemos notar que existe una correlación negativa entre los años transcurridos entre la construcción y la remodelación de la casa con el precio de venta, por lo que a mayor tiempo, menor será su valor de venta, ya que esto puede verse reflejado en detalles estructurales y estéticos del inmueble.

# %%
cols=['TimeBuilt', "TimeRemo", 'SalePrice']
df=stories[cols]
fig,axes = plt.subplots(figsize = (12,6), nrows = 1, ncols = 2)
for i in range(2):
    plt.sca(axes[i])
    plt.scatter(df.iloc[:,i],df['SalePrice'], color='#237c18', alpha = 0.3)
    plt.xlabel(df.iloc[:,i].name)
    plt.ylabel('SalesPrice')
